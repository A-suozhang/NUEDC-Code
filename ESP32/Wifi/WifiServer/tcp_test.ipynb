# %%
# %matplotlib notebook
import socket
import matplotlib.pyplot as plt
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# addr = ('192.168.43.24',100)
addr = ('192.168.43.237',100)
# addr = ('192.168.50.123',100)
sock.connect(addr)
print("Connected.")
# sock.sendall(bytes(1))

# while(True):
#     dat = sock.recv(1)
# #     print(dat)
#     if (dat == b'\xff'):
#         sock.sendall(bytes(1))
#     else:
#         sock.sendall(dat)
# Out:
# Connected.

# %%
sock.sendall('!'.encode())
data = sock.recv(1024)

# %%
import matplotlib.pyplot as plt

len(data[1:41])
l = []
for i in range(len(data)-1):
    l.append(data[i+1])

# %%
plt.plot(l)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
l
# Out:
# [115,
#  115,
#  115,
#  116,
#  116,
#  118,
#  129,
#  172,
#  174,
#  166,
#  169,
#  173,
#  177,
#  181,
#  185,
#  188,
#  190,
#  192,
#  194,
#  195,
#  195,
#  195,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196,
#  196]

# %%
# ----------- The Dynamic Plotting --------------
# %matplotlib inline
# %matplotlib notebook
import time

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

# for i in range(100):
while(True):
    ax.clear()
    dat = sock.recv(100)
    # type(dat.decode());
    # dat_str = dat.decode();
    # type(dat[19]);
    l = [];
    for i in range(len(dat)):
        l.append(dat[i])
    ax.plot(l)
    fig.canvas.draw()
    time.sleep(0.05)




# for i in range(len(dat_str)):
#     print (i, dat_str[i]);
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-65f27c1af94d> in <module>()
#      13 # for i in range(100):
#      14 while(True):
# ---> 15     ax.clear()
#      16     dat = sock.recv(100)
#      17     # type(dat.decode());
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in clear(self)
#    1144     def clear(self):
#    1145         """Clear the axes."""
# -> 1146         self.cla()
#    1147
#    1148     def get_facecolor(self):
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1013
#    1014         for name, spine in six.iteritems(self.spines):
# -> 1015             spine.cla()
#    1016
#    1017         self.ignore_existing_data_limits = True
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\spines.py in cla(self)
#     178         self._position = None  # clear position
#     179         if self.axis is not None:
# --> 180             self.axis.cla()
#     181
#     182     def is_frame_like(self):
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in cla(self)
#     815                              rcParams['axes.grid.which'] in ('both', 'minor'))
#     816
# --> 817         self.reset_ticks()
#     818
#     819         self.converter = None
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     838             pass
#     839         try:
# --> 840             self.set_clip_path(self.axes.patch)
#     841         except AttributeError:
#     842             pass
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in set_clip_path(self, clippath, transform)
#     927     def set_clip_path(self, clippath, transform=None):
#     928         artist.Artist.set_clip_path(self, clippath, transform)
# --> 929         for child in self.majorTicks + self.minorTicks:
#     930             child.set_clip_path(clippath, transform)
#     931         self.stale = True
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     679             if self._major:
#     680                 instance.majorTicks = []
# --> 681                 tick = instance._get_tick(major=True)
#     682                 instance.majorTicks.append(tick)
#     683                 return instance.majorTicks
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2162         else:
#    2163             tick_kw = self._minor_tick_kw
# -> 2164         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2165
#    2166     def _get_label(self):
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     174         self.apply_tickdir(tickdir)
#     175
# --> 176         self.tick1line = self._get_tick1line()
#     177         self.tick2line = self._get_tick2line()
#     178         self.gridline = self._get_gridline()
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in _get_tick1line(self)
#     598                           markeredgewidth=self._width,
#     599                           zorder=self._zorder)
# --> 600         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     601         self._set_artist_props(l)
#     602         return l
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in get_yaxis_transform(self, which)
#     782         elif which == 'tick1':
#     783             # for cartesian projection, this is bottom spine
# --> 784             return self.spines['left'].get_spine_transform()
#     785         elif which == 'tick2':
#     786             # for cartesian projection, this is top spine
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\spines.py in get_spine_transform(self)
#     436     def get_spine_transform(self):
#     437         """get the spine transform"""
# --> 438         self._ensure_position_is_set()
#     439         what, how = self._spine_transform
#     440
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\spines.py in _ensure_position_is_set(self)
#     160             # default position
#     161             self._position = ('outward', 0.0)  # in points
# --> 162             self.set_position(self._position)
#     163
#     164     def register_axis(self, axis):
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\spines.py in set_position(self, position)
#     426
#     427         if self.axis is not None:
# --> 428             self.axis.reset_ticks()
#     429         self.stale = True
#     430
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     838             pass
#     839         try:
# --> 840             self.set_clip_path(self.axes.patch)
#     841         except AttributeError:
#     842             pass
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in set_clip_path(self, clippath, transform)
#     927     def set_clip_path(self, clippath, transform=None):
#     928         artist.Artist.set_clip_path(self, clippath, transform)
# --> 929         for child in self.majorTicks + self.minorTicks:
#     930             child.set_clip_path(clippath, transform)
#     931         self.stale = True
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     684             else:
#     685                 instance.minorTicks = []
# --> 686                 tick = instance._get_tick(major=False)
#     687                 instance.minorTicks.append(tick)
#     688                 return instance.minorTicks
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2162         else:
#    2163             tick_kw = self._minor_tick_kw
# -> 2164         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2165
#    2166     def _get_label(self):
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     175
#     176         self.tick1line = self._get_tick1line()
# --> 177         self.tick2line = self._get_tick2line()
#     178         self.gridline = self._get_gridline()
#     179
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axis.py in _get_tick2line(self)
#     611                           markersize=self._size,
#     612                           markeredgewidth=self._width,
# --> 613                           zorder=self._zorder)
#     614         l.set_transform(self.axes.get_yaxis_transform(which='tick2'))
#     615         self._set_artist_props(l)
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     395         self._color = None
#     396         self.set_color(color)
# --> 397         self._marker = MarkerStyle(marker, fillstyle)
#     398
#     399         self._markevery = None
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     187         self._marker_function = None
#     188         self.set_fillstyle(fillstyle)
# --> 189         self.set_marker(marker)
#     190
#     191     def __getstate__(self):
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     273
#     274         self._marker = marker
# --> 275         self._recache()
#     276
#     277     def get_path(self):
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\markers.py in _recache(self)
#     209         self._capstyle = 'butt'
#     210         self._filled = True
# --> 211         self._marker_function()
#     212
#     213     if six.PY3:
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\markers.py in _set_tickright(self)
#     707
#     708     def _set_tickright(self):
# --> 709         self._transform = Affine2D().scale(1.0, 1.0)
#     710         self._snap_threshold = 1.0
#     711         self._filled = False
#
# c:\users\a_suozhang\appdata\local\programs\python\python36\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    2089         scale_mtx = np.array(
#    2090             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 2091         self._mtx = np.dot(scale_mtx, self._mtx)
#    2092         self.invalidate()
#    2093         return self
#
# KeyboardInterrupt:

# %%
sock.send('Hello ESP32\n'.encode())
# If NOT Encode() The Element is String ,But Byte String Needede

# %%
while(True):
    dat = sock.recv(1)
    if (dat[0] == 255):
        sock.sendall(0x00)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-868d730a2246> in <module>()
#       1 while(True):
# ----> 2     dat = sock.recv(1)
#       3     if (dat[0] == 255):
#       4         sock.sendall(0x00)
#
# OSError: [WinError 10038] 在一个非套接字上尝试了一个操作。
